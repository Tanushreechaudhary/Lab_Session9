# %% [markdown]
# # Lab Session 9 - Jupyter Notebook
#
# This is a redesign version of lab session 6 where we have to develop an interactive representation of the data we have collected. We have to present persuasive arguments showing why recruiters should hire students studying at Santa Clara University.<br />
# Data sources are mentioned below: <br />
# Data about Mid career Salary - https://www.payscale.com/  <br />
# Data about University Rankings - https://patch.com <br />
# Data about MSIS skill set is taken from data shared by fellow classmates. <br />
#
# In the Jupyter notebook, I will be using the downloaded data and integrating it into one dataset.

# %% [markdown]
# #### Importing pandas library with the alias pd

# %%
import pandas as pd

# %% [markdown]
# #### Reading the csv files downloaded and save on the machine

# %%
MidCareerSalary = pd.read_csv(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab9_Session\FinalSheets\MidSalary.csv")
Rankings = pd.read_csv(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab9_Session\FinalSheets\Rankings in CA.csv")
SkillSet = pd.read_csv(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab9_Session\FinalSheets\Skillset.csv")

# %% [markdown]
# #### Displaying the first five rows of data about mid career salary

# %%
MidCareerSalary.head()
# Out:
#    Mid Career Salary                                      University
# 0             104000  California State University - Fullerton (CSUF)
# 1             118000      Golden Gate University - San Francisco, CA
# 2             111000                San Jose State University (SJSU)
# 3             140000                          Santa Clara University
# 4             144000                             Stanford University

# %% [markdown]
# #### Displaying first five rows of university rankings data

# %%
Rankings.head()
# Out:
#    Ranking in CA                                      University
# 0             61  California State University - Fullerton (CSUF)
# 1             13      Golden Gate University - San Francisco, CA
# 2             35                San Jose State University (SJSU)
# 3              2                          Santa Clara University
# 4              1                             Stanford University

# %% [markdown]
# #### Merging the Rankings and Mid career salary data based on University

# %%
merge1 = MidCareerSalary.merge(Rankings, on="University", how="outer")

# %%
merge1.head()
# Out:
#    Mid Career Salary                                      University  \
# 0             104000  California State University - Fullerton (CSUF)
# 1             118000      Golden Gate University - San Francisco, CA
# 2             111000                San Jose State University (SJSU)
# 3             140000                          Santa Clara University
# 4             144000                             Stanford University
#
#    Ranking in CA
# 0             61
# 1             13
# 2             35
# 3              2
# 4              1

# %% [markdown]
# #### Displaying the first five rows of MSIS skill set data

# %%
SkillSet.head()
# Out:
#    Category                 Skills  Number of People
# 0  Business      Business Analysis                90
# 1  Business  Business Intelligence                59
# 2  Business          Data Analysis               101
# 3  Business             Leadership                75
# 4  Business             Management                97

# %% [markdown]
# #### The two data sets (Skill set data and merge1 data)do not have any common key, so will be concatenating them row wise

# %%
merge2 = pd.concat([merge1,SkillSet])

# %%
merge2
# Out:
#      Category  Mid Career Salary  Number of People  Ranking in CA  \
# 0         NaN           104000.0               NaN           61.0
# 1         NaN           118000.0               NaN           13.0
# 2         NaN           111000.0               NaN           35.0
# 3         NaN           140000.0               NaN            2.0
# 4         NaN           144000.0               NaN            1.0
# 5         NaN           117000.0               NaN           16.0
# 6         NaN           107000.0               NaN           50.0
# 7         NaN           119000.0               NaN           12.0
# 8         NaN           106000.0               NaN           52.0
# 9         NaN           122000.0               NaN           10.0
# 10        NaN           109000.0               NaN           42.0
# 11        NaN           111000.0               NaN           35.0
# 12        NaN           107000.0               NaN           50.0
# ...

# %% [markdown]
# #### Exporting the data as csv file

# %%
merge2.to_csv("LabSession_9.csv")
